# %% [markdown]
# # Data preparation
# ## Read and show Excel data for one day from Flightradar

# %%
import pandas as pd

# %%
# XLSX-Datei laden
flightradar = pd.read_excel("raw/250518_flightradar.xlsx")

# Erste 5 Zeilen anzeigen
print(flightradar.head(5))
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1747631713-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1747631713-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1747631713-3  https://www.flightradar24.com/data/airports/zr...   NaN
# 3      1747631713-4  https://www.flightradar24.com/data/airports/zr...   NaN
# 4      1747631713-5  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  FLIGHT  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   CS638
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   CS600
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  W22160
# 3    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  W22178
# 4    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK130
#
#        DESTINATION           AIRLINE       AIRCRAFT          STATUS
# 0     Ohrid (OHD)-  Chair Airlines -  A320 (HB-JOP)  Departed 06:00
# 1  Pristina (PRN)-  Chair Airlines -  A320 (HB-JOS)  Departed 06:02
# 2  Pristina (PRN)-      Flexflight -         320 ()         Unknown
# 3     Ohrid (OHD)-      Flexflight -         320 ()         Unknown
# 4  Hurghada (HRG)-   Edelweiss Air -  A320 (HB-IHX)  Departed 06:09

# %% [markdown]
# ## Show data types and shape of the DataFrame

# %%
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# dtype: object
# (387, 15)

# %% [markdown]
# ## The Date is missing in the DataFrame. Create a new field DATETIME
# ### DATETIME is the planned departure time for that day

# %%
# Datum als Variable definieren
date_str = "2025-05-18"

# %%
# TIME als String sicherstellen (falls es z. B. float ist)
flightradar["TIME"] = flightradar["TIME"].astype(str)

# DATETIME-Feld erzeugen: 'date_str' + Zeit aus TIME-Feld
flightradar["DATETIME"] = date_str + " " + flightradar["TIME"]

# Kontrolle
print(flightradar[["TIME", "DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#         TIME             DATETIME
# 0   05:45:00  2025-05-18 05:45:00
# 1   05:45:00  2025-05-18 05:45:00
# 2   05:45:00  2025-05-18 05:45:00
# 3   05:45:00  2025-05-18 05:45:00
# 4   06:00:00  2025-05-18 06:00:00
# 5   06:00:00  2025-05-18 06:00:00
# 6   06:10:00  2025-05-18 06:10:00
# 7   06:10:00  2025-05-18 06:10:00
# 8   06:20:00  2025-05-18 06:20:00
# 9   06:20:00  2025-05-18 06:20:00
# 10  06:25:00  2025-05-18 06:25:00
# 11  06:25:00  2025-05-18 06:25:00
# 12  06:25:00  2025-05-18 06:25:00
# 13  06:30:00  2025-05-18 06:30:00
# 14  06:30:00  2025-05-18 06:30:00
# 15  06:35:00  2025-05-18 06:35:00
# 16  06:35:00  2025-05-18 06:35:00
# 17  06:40:00  2025-05-18 06:40:00
# 18  06:45:00  2025-05-18 06:45:00
# 19  06:45:00  2025-05-18 06:45:00
# 20  06:45:00  2025-05-18 06:45:00
# 21  06:45:00  2025-05-18 06:45:00
# 22  06:50:00  2025-05-18 06:50:00
# 23  06:50:00  2025-05-18 06:50:00
# 24  06:50:00  2025-05-18 06:50:00
# 25  06:55:00  2025-05-18 06:55:00
# 26  06:55:00  2025-05-18 06:55:00
# 27  06:55:00  2025-05-18 06:55:00
# 28  07:00:00  2025-05-18 07:00:00
# 29  07:00:00  2025-05-18 07:00:00
# 30  07:00:00  2025-05-18 07:00:00
# 31  07:00:00  2025-05-18 07:00:00
# 32  07:00:00  2025-05-18 07:00:00
# 33  07:00:00  2025-05-18 07:00:00
# 34  07:05:00  2025-05-18 07:05:00
# 35  07:05:00  2025-05-18 07:05:00
# 36  07:05:00  2025-05-18 07:05:00
# 37  07:05:00  2025-05-18 07:05:00
# 38  07:05:00  2025-05-18 07:05:00
# 39  07:10:00  2025-05-18 07:10:00
# 40  07:10:00  2025-05-18 07:10:00
# 41  07:10:00  2025-05-18 07:10:00
# 42  07:10:00  2025-05-18 07:10:00
# 43  07:15:00  2025-05-18 07:15:00
# 44  07:15:00  2025-05-18 07:15:00
# 45  07:15:00  2025-05-18 07:15:00
# 46  07:20:00  2025-05-18 07:20:00
# 47  07:20:00  2025-05-18 07:20:00
# 48  07:20:00  2025-05-18 07:20:00
# 49  07:20:00  2025-05-18 07:20:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# dtype: object
# (387, 16)

# %% [markdown]
# ## Create two new fields: DESTINATION_CLEAN and IATA_CODE using regex

# %%
# DESTINATION_CLEAN: Alles vor der Klammer
flightradar["DESTINATION_CLEAN"] = flightradar["DESTINATION"].str.extract(r"^(.*?)\s*\(")

# IATA-CODE: Inhalt in der Klammer
flightradar["IATA_CODE"] = flightradar["DESTINATION"].str.extract(r"\((\w{3})\)")

# Kontrolle
print(flightradar[["DESTINATION", "DESTINATION_CLEAN", "IATA_CODE"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                  DESTINATION  DESTINATION_CLEAN IATA_CODE
# 0               Ohrid (OHD)-              Ohrid       OHD
# 1            Pristina (PRN)-           Pristina       PRN
# 2            Pristina (PRN)-           Pristina       PRN
# 3               Ohrid (OHD)-              Ohrid       OHD
# 4            Hurghada (HRG)-           Hurghada       HRG
# 5             Antalya (AYT)-            Antalya       AYT
# 6              Athens (ATH)-             Athens       ATH
# 7              Lisbon (LIS)-             Lisbon       LIS
# 8               Porto (OPO)-              Porto       OPO
# 9            Tenerife (TFS)-           Tenerife       TFS
# 10       Gran Canaria (LPA)-       Gran Canaria       LPA
# 11         Marsa Alam (RMF)-         Marsa Alam       RMF
# 12             Bilbao (BIO)-             Bilbao       BIO
# 13      Fuerteventura (FUE)-      Fuerteventura       FUE
# 14          Lanzarote (ACE)-          Lanzarote       ACE
# 15             Dublin (DUB)-             Dublin       DUB
# 16             Djerba (DJE)-             Djerba       DJE
# 17          Heraklion (HER)-          Heraklion       HER
# 18             Skopje (SKP)-             Skopje       SKP
# 19  Palma de Mallorca (PMI)-  Palma de Mallorca       PMI
# 20           Pristina (PRN)-           Pristina       PRN
# 21             Skopje (SKP)-             Skopje       SKP
# 22             Warsaw (WAW)-             Warsaw       WAW
# 23       Thessaloniki (SKG)-       Thessaloniki       SKG
# 24  Palma de Mallorca (PMI)-  Palma de Mallorca       PMI
# 25          Frankfurt (FRA)-          Frankfurt       FRA
# 26           Belgrade (BEG)-           Belgrade       BEG
# 27             Madrid (MAD)-             Madrid       MAD
# 28          Amsterdam (AMS)-          Amsterdam       AMS
# 29           Sarajevo (SJJ)-           Sarajevo       SJJ
# 30            Palermo (PMO)-            Palermo       PMO
# 31           Valencia (VLC)-           Valencia       VLC
# 32            Palermo (PMO)-            Palermo       PMO
# 33           Sarajevo (SJJ)-           Sarajevo       SJJ
# 34             London (LHR)-             London       LHR
# 35         Manchester (MAN)-         Manchester       MAN
# 36             Tirana (TIA)-             Tirana       TIA
# 37             Naples (NAP)-             Naples       NAP
# 38             London (LHR)-             London       LHR
# 39         Dusseldorf (DUS)-         Dusseldorf       DUS
# 40         Copenhagen (CPH)-         Copenhagen       CPH
# 41          Barcelona (BCN)-          Barcelona       BCN
# 42           Budapest (BUD)-           Budapest       BUD
# 43            Hamburg (HAM)-            Hamburg       HAM
# 44             Munich (MUC)-             Munich       MUC
# 45          Dubrovnik (DBV)-          Dubrovnik       DBV
# 46          Amsterdam (AMS)-          Amsterdam       AMS
# 47             Berlin (BER)-             Berlin       BER
# 48             Vienna (VIE)-             Vienna       VIE
# 49               Rome (FCO)-               Rome       FCO
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# dtype: object
# (387, 18)

# %% [markdown]
# ## Create three new fields: CANCELED, DEPART_TIME and DEPART_DATETIME using regex

# %%
# 1. CANCELED-Spalte (Boolean)
flightradar["CANCELED"] = flightradar["STATUS"].str.contains("Canceled", na=False)

# 2. DEPART_TIME-Spalte (nur wenn "Departed HH:MM" enthalten ist)
flightradar["DEPART_TIME"] = flightradar["STATUS"].str.extract(r"Departed\s*(\d{2}:\d{2})")[0]

# 3. DEPART_DATETIME-Spalte: date_str + DEPART_TIME (fallback "00:00") + ":00"
flightradar["DEPART_DATETIME"] = (
    date_str
    + " "
    + flightradar["DEPART_TIME"].fillna("00:00") # falls keine Zeit da ist, setze "00:00"
    + ":00" # Sekunden anhängen
)

# Kontrolle
print(flightradar[["STATUS","CANCELED","DEPART_TIME","DEPART_DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                    STATUS  CANCELED DEPART_TIME      DEPART_DATETIME
# 0          Departed 06:00     False       06:00  2025-05-18 06:00:00
# 1          Departed 06:02     False       06:02  2025-05-18 06:02:00
# 2                 Unknown     False         NaN  2025-05-18 00:00:00
# 3                 Unknown     False         NaN  2025-05-18 00:00:00
# 4          Departed 06:09     False       06:09  2025-05-18 06:09:00
# 5          Departed 06:11     False       06:11  2025-05-18 06:11:00
# 6          Departed 06:53     False       06:53  2025-05-18 06:53:00
# 7          Departed 06:21     False       06:21  2025-05-18 06:21:00
# 8          Departed 06:49     False       06:49  2025-05-18 06:49:00
# 9          Departed 06:47     False       06:47  2025-05-18 06:47:00
# 10         Departed 06:39     False       06:39  2025-05-18 06:39:00
# 11         Departed 06:41     False       06:41  2025-05-18 06:41:00
# 12         Departed 06:51     False       06:51  2025-05-18 06:51:00
# 13         Departed 06:43     False       06:43  2025-05-18 06:43:00
# 14         Departed 07:00     False       07:00  2025-05-18 07:00:00
# 15         Departed 07:02     False       07:02  2025-05-18 07:02:00
# 16         Departed 07:23     False       07:23  2025-05-18 07:23:00
# 17         Departed 06:58     False       06:58  2025-05-18 06:58:00
# 18         Departed 06:45     False       06:45  2025-05-18 06:45:00
# 19         Departed 07:05     False       07:05  2025-05-18 07:05:00
# 20         Departed 06:56     False       06:56  2025-05-18 06:56:00
# 21                Unknown     False         NaN  2025-05-18 00:00:00
# 22         Departed 07:11     False       07:11  2025-05-18 07:11:00
# 23         Departed 07:04     False       07:04  2025-05-18 07:04:00
# 24         Departed 07:08     False       07:08  2025-05-18 07:08:00
# 25         Departed 07:10     False       07:10  2025-05-18 07:10:00
# 26         Departed 07:15     False       07:15  2025-05-18 07:15:00
# 27         Departed 07:16     False       07:16  2025-05-18 07:16:00
# 28         Departed 07:23     False       07:23  2025-05-18 07:23:00
# 29         Departed 07:17     False       07:17  2025-05-18 07:17:00
# 30  Estimated dep.  07:00     False         NaN  2025-05-18 00:00:00
# 31         Departed 07:18     False       07:18  2025-05-18 07:18:00
# 32         Departed 07:12     False       07:12  2025-05-18 07:12:00
# 33         Departed 09:31     False       09:31  2025-05-18 09:31:00
# 34         Departed 07:21     False       07:21  2025-05-18 07:21:00
# 35         Departed 07:41     False       07:41  2025-05-18 07:41:00
# 36         Departed 07:13     False       07:13  2025-05-18 07:13:00
# 37         Departed 07:20     False       07:20  2025-05-18 07:20:00
# 38  Estimated dep.  07:21     False         NaN  2025-05-18 00:00:00
# 39         Departed 07:28     False       07:28  2025-05-18 07:28:00
# 40         Departed 07:26     False       07:26  2025-05-18 07:26:00
# 41         Departed 07:26     False       07:26  2025-05-18 07:26:00
# 42         Departed 07:31     False       07:31  2025-05-18 07:31:00
# 43         Departed 07:34     False       07:34  2025-05-18 07:34:00
# 44         Departed 07:39     False       07:39  2025-05-18 07:39:00
# 45         Departed 07:36     False       07:36  2025-05-18 07:36:00
# 46         Departed 07:45     False       07:45  2025-05-18 07:45:00
# 47         Departed 07:42     False       07:42  2025-05-18 07:42:00
# 48         Departed 07:40     False       07:40  2025-05-18 07:40:00
# 49         Departed 07:34     False       07:34  2025-05-18 07:34:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# dtype: object
# (387, 21)

# %% [markdown]
# ## Creating the AIRLINE_CLEAN field and removing unimportant parts

# %%
flightradar["AIRLINE_CLEAN"] = (
    flightradar["AIRLINE"]
      .str.extract(r'^(.+?)(?=\s*(?:\(|-))')[0]  # Gruppe 1: alles bis vor "(" oder "-"
      .str.strip()                               # führende/trailing Leerzeichen entfernen
)

# Kontrolle
print(flightradar[["AIRLINE","AIRLINE_CLEAN"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                                    AIRLINE     AIRLINE_CLEAN
# 0                         Chair Airlines -    Chair Airlines
# 1                         Chair Airlines -    Chair Airlines
# 2                             Flexflight -        Flexflight
# 3                             Flexflight -        Flexflight
# 4                          Edelweiss Air -     Edelweiss Air
# 5                          Edelweiss Air -     Edelweiss Air
# 6                       Helvetic Airways -  Helvetic Airways
# 7                       TAP Air Portugal -  TAP Air Portugal
# 8                                  Swiss -             Swiss
# 9                          Edelweiss Air -     Edelweiss Air
# 10                         Edelweiss Air -     Edelweiss Air
# 11                         Edelweiss Air -     Edelweiss Air
# 12                                 Swiss -             Swiss
# 13                         Edelweiss Air -     Edelweiss Air
# 14  Edelweiss Air (Help Alliance Livery) -     Edelweiss Air
# 15                                 Swiss -             Swiss
# 16                         Edelweiss Air -     Edelweiss Air
# 17                         Edelweiss Air -     Edelweiss Air
# 18                        Chair Airlines -    Chair Airlines
# 19                         Edelweiss Air -     Edelweiss Air
# 20                                 Swiss -             Swiss
# 21                            Flexflight -        Flexflight
# 22                      Helvetic Airways -  Helvetic Airways
# 23                      Helvetic Airways -  Helvetic Airways
# 24                                 Swiss -             Swiss
# 25                      Helvetic Airways -  Helvetic Airways
# 26                                 Swiss -             Swiss
# 27                      Helvetic Airways -  Helvetic Airways
# 28                                   KLM -               KLM
# 29                                 Swiss -             Swiss
# 30                                 Swiss -             Swiss
# 31                                 Swiss -             Swiss
# 32                                 Swiss -             Swiss
# 33                                 Swiss -             Swiss
# 34                                 Swiss -             Swiss
# 35                      Helvetic Airways -  Helvetic Airways
# 36                                 Swiss -             Swiss
# 37                                 Swiss -             Swiss
# 38                                 Swiss -             Swiss
# 39                      Helvetic Airways -  Helvetic Airways
# 40                            Air Baltic -        Air Baltic
# 41                                 Swiss -             Swiss
# 42                                 Swiss -             Swiss
# 43                                 Swiss -             Swiss
# 44                      Helvetic Airways -  Helvetic Airways
# 45                                 Swiss -             Swiss
# 46                      Helvetic Airways -  Helvetic Airways
# 47                            Air Baltic -        Air Baltic
# 48                                 Swiss -             Swiss
# 49                                 Swiss -             Swiss
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# dtype: object
# (387, 22)

# %% [markdown]
# ## Creating the AIRCRAFT_SHORT field

# %%
# Create the AIRCRAFT_SHORT field by removing text inside parentheses
flightradar["AIRCRAFT_SHORT"] = (
    flightradar["AIRCRAFT"]
      .str.replace(r"\s*\(.*?\)", "", regex=True)  # non‑greedy, regex=True
      .str.strip()
)

# Check the result
print(flightradar[["AIRCRAFT", "AIRCRAFT_SHORT"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#          AIRCRAFT AIRCRAFT_SHORT
# 0   A320 (HB-JOP)           A320
# 1   A320 (HB-JOS)           A320
# 2          320 ()            320
# 3          320 ()            320
# 4   A320 (HB-IHX)           A320
# 5   A320 (HB-JLS)           A320
# 6   E295 (HB-AZI)           E295
# 7   A20N (CS-TVA)           A20N
# 8   BCS3 (HB-JCF)           BCS3
# 9   A320 (HB-IHY)           A320
# 10  A320 (HB-IJU)           A320
# 11  A320 (HB-JJM)           A320
# 12  A320 (HB-IJI)           A320
# 13  A320 (HB-JJN)           A320
# 14  A320 (HB-JLT)           A320
# 15  BCS3 (HB-JCD)           BCS3
# 16  A320 (HB-JLP)           A320
# 17  A320 (HB-IJV)           A320
# 18  A319 (HB-JOJ)           A319
# 19  A320 (HB-JLR)           A320
# 20  A320 (HB-IJQ)           A320
# 21         320 ()            320
# 22  E290 (HB-AZG)           E290
# 23  E190 (HB-JVY)           E190
# 24  A21N (HB-JPA)           A21N
# 25  E295 (HB-AZJ)           E295
# 26  A321 (HB-IOD)           A321
# 27  E295 (HB-AZL)           E295
# 28  B738 (PH-BXZ)           B738
# 29  BCS1 (HB-JBF)           BCS1
# 30  A20N (HB-JDI)           A20N
# 31  BCS3 (HB-JCJ)           BCS3
# 32  A20N (HB-JDI)           A20N
# 33  BCS1 (HB-JBF)           BCS1
# 34  A21N (HB-JPC)           A21N
# 35  E190 (HB-JVN)           E190
# 36  BCS3 (HB-JCB)           BCS3
# 37  BCS3 (HB-JCN)           BCS3
# 38  A21N (HB-JPC)           A21N
# 39  E195 (HB-JVW)           E195
# 40  BCS3 (YL-ABL)           BCS3
# 41  A321 (HB-IOH)           A321
# 42  A320 (HB-JLQ)           A320
# 43  A20N (HB-JDJ)           A20N
# 44  E195 (HB-JVJ)           E195
# 45  BCS1 (HB-JBI)           BCS1
# 46  E290 (HB-AZA)           E290
# 47  BCS3 (YL-CSN)           BCS3
# 48  A321 (HB-ION)           A321
# 49  A320 (HB-IJP)           A320
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# AIRCRAFT_SHORT            object
# dtype: object
# (387, 23)

# %% [markdown]
# ## Create a new field DELAY and DELAY_MINUTES and calculate it from DATETIME and DEPART_DATETIME

# %%
# 1) Stelle sicher, dass beide Spalten als datetime64 vorliegen
flightradar["DATETIME"] = pd.to_datetime(flightradar["DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")
flightradar["DEPART_DATETIME"] = pd.to_datetime(flightradar["DEPART_DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")

# 2) DELAY als Differenz berechnen
flightradar["DELAY"] = flightradar["DEPART_DATETIME"] - flightradar["DATETIME"]

# 3a) Variante A: Floor‑Division auf total_seconds, dann in int
flightradar["DELAY_MINUTES"] = (
    flightradar["DELAY"].dt.total_seconds() // 60
).astype(int)

# Kontrolle
print(flightradar[["DATETIME","DEPART_DATETIME","DELAY","DELAY_MINUTES"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#               DATETIME     DEPART_DATETIME             DELAY  DELAY_MINUTES
# 0  2025-05-18 05:45:00 2025-05-18 06:00:00   0 days 00:15:00             15
# 1  2025-05-18 05:45:00 2025-05-18 06:02:00   0 days 00:17:00             17
# 2  2025-05-18 05:45:00 2025-05-18 00:00:00 -1 days +18:15:00           -345
# 3  2025-05-18 05:45:00 2025-05-18 00:00:00 -1 days +18:15:00           -345
# 4  2025-05-18 06:00:00 2025-05-18 06:09:00   0 days 00:09:00              9
# 5  2025-05-18 06:00:00 2025-05-18 06:11:00   0 days 00:11:00             11
# 6  2025-05-18 06:10:00 2025-05-18 06:53:00   0 days 00:43:00             43
# 7  2025-05-18 06:10:00 2025-05-18 06:21:00   0 days 00:11:00             11
# 8  2025-05-18 06:20:00 2025-05-18 06:49:00   0 days 00:29:00             29
# 9  2025-05-18 06:20:00 2025-05-18 06:47:00   0 days 00:27:00             27
# 10 2025-05-18 06:25:00 2025-05-18 06:39:00   0 days 00:14:00             14
# 11 2025-05-18 06:25:00 2025-05-18 06:41:00   0 days 00:16:00             16
# 12 2025-05-18 06:25:00 2025-05-18 06:51:00   0 days 00:26:00             26
# 13 2025-05-18 06:30:00 2025-05-18 06:43:00   0 days 00:13:00             13
# 14 2025-05-18 06:30:00 2025-05-18 07:00:00   0 days 00:30:00             30
# 15 2025-05-18 06:35:00 2025-05-18 07:02:00   0 days 00:27:00             27
# 16 2025-05-18 06:35:00 2025-05-18 07:23:00   0 days 00:48:00             48
# 17 2025-05-18 06:40:00 2025-05-18 06:58:00   0 days 00:18:00             18
# 18 2025-05-18 06:45:00 2025-05-18 06:45:00   0 days 00:00:00              0
# 19 2025-05-18 06:45:00 2025-05-18 07:05:00   0 days 00:20:00             20
# 20 2025-05-18 06:45:00 2025-05-18 06:56:00   0 days 00:11:00             11
# 21 2025-05-18 06:45:00 2025-05-18 00:00:00 -1 days +17:15:00           -405
# 22 2025-05-18 06:50:00 2025-05-18 07:11:00   0 days 00:21:00             21
# 23 2025-05-18 06:50:00 2025-05-18 07:04:00   0 days 00:14:00             14
# 24 2025-05-18 06:50:00 2025-05-18 07:08:00   0 days 00:18:00             18
# 25 2025-05-18 06:55:00 2025-05-18 07:10:00   0 days 00:15:00             15
# 26 2025-05-18 06:55:00 2025-05-18 07:15:00   0 days 00:20:00             20
# 27 2025-05-18 06:55:00 2025-05-18 07:16:00   0 days 00:21:00             21
# 28 2025-05-18 07:00:00 2025-05-18 07:23:00   0 days 00:23:00             23
# 29 2025-05-18 07:00:00 2025-05-18 07:17:00   0 days 00:17:00             17
# 30 2025-05-18 07:00:00 2025-05-18 00:00:00 -1 days +17:00:00           -420
# 31 2025-05-18 07:00:00 2025-05-18 07:18:00   0 days 00:18:00             18
# 32 2025-05-18 07:00:00 2025-05-18 07:12:00   0 days 00:12:00             12
# 33 2025-05-18 07:00:00 2025-05-18 09:31:00   0 days 02:31:00            151
# 34 2025-05-18 07:05:00 2025-05-18 07:21:00   0 days 00:16:00             16
# 35 2025-05-18 07:05:00 2025-05-18 07:41:00   0 days 00:36:00             36
# 36 2025-05-18 07:05:00 2025-05-18 07:13:00   0 days 00:08:00              8
# 37 2025-05-18 07:05:00 2025-05-18 07:20:00   0 days 00:15:00             15
# 38 2025-05-18 07:05:00 2025-05-18 00:00:00 -1 days +16:55:00           -425
# 39 2025-05-18 07:10:00 2025-05-18 07:28:00   0 days 00:18:00             18
# 40 2025-05-18 07:10:00 2025-05-18 07:26:00   0 days 00:16:00             16
# 41 2025-05-18 07:10:00 2025-05-18 07:26:00   0 days 00:16:00             16
# 42 2025-05-18 07:10:00 2025-05-18 07:31:00   0 days 00:21:00             21
# 43 2025-05-18 07:15:00 2025-05-18 07:34:00   0 days 00:19:00             19
# 44 2025-05-18 07:15:00 2025-05-18 07:39:00   0 days 00:24:00             24
# 45 2025-05-18 07:15:00 2025-05-18 07:36:00   0 days 00:21:00             21
# 46 2025-05-18 07:20:00 2025-05-18 07:45:00   0 days 00:25:00             25
# 47 2025-05-18 07:20:00 2025-05-18 07:42:00   0 days 00:22:00             22
# 48 2025-05-18 07:20:00 2025-05-18 07:40:00   0 days 00:20:00             20
# 49 2025-05-18 07:20:00 2025-05-18 07:34:00   0 days 00:14:00             14
#
#
# web-scraper-order                 object
# web-scraper-start-url             object
# page                             float64
# page2                            float64
# page3                            float64
# page4                            float64
# page5                            float64
# page6                            float64
# page7                            float64
# TIME                              object
# FLIGHT                            object
# DESTINATION                       object
# AIRLINE                           object
# AIRCRAFT                          object
# STATUS                            object
# DATETIME                  datetime64[ns]
# DESTINATION_CLEAN                 object
# IATA_CODE                         object
# CANCELED                            bool
# DEPART_TIME                       object
# DEPART_DATETIME           datetime64[ns]
# AIRLINE_CLEAN                     object
# AIRCRAFT_SHORT                    object
# DELAY                    timedelta64[ns]
# DELAY_MINUTES                      int64
# dtype: object
# (387, 25)

# %% [markdown]
# ## Showing full DataFrame

# %%
flightradar.head(3)
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1747631713-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1747631713-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1747631713-3  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  ...  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
#
#              DATETIME DESTINATION_CLEAN IATA_CODE CANCELED DEPART_TIME  \
# 0 2025-05-18 05:45:00             Ohrid       OHD    False       06:00
# 1 2025-05-18 05:45:00          Pristina       PRN    False       06:02
# 2 2025-05-18 05:45:00          Pristina       PRN    False         NaN
#
#       DEPART_DATETIME   AIRLINE_CLEAN AIRCRAFT_SHORT             DELAY  \
# 0 2025-05-18 06:00:00  Chair Airlines           A320   0 days 00:15:00
# 1 2025-05-18 06:02:00  Chair Airlines           A320   0 days 00:17:00
# 2 2025-05-18 00:00:00      Flexflight            320 -1 days +18:15:00
#
#   DELAY_MINUTES
# 0            15
# 1            17
# 2          -345
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Creating a New DataFrame with Selected Columns

# %%
# Create a new DataFrame with selected columns
flightradar_clean = flightradar[[
    "DESTINATION_CLEAN", 
    "IATA_CODE", 
    "AIRLINE_CLEAN", 
    "AIRCRAFT_SHORT", 
    "CANCELED", 
    "DATETIME",
    "DEPART_TIME", 
    "DEPART_DATETIME", 
    "DELAY_MINUTES"
]].copy()

# Check the result
print(flightradar_clean.head(50))
print("\n")
print(flightradar_clean.dtypes)
print(flightradar_clean.shape)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0               Ohrid       OHD    Chair Airlines           A320     False
# 1            Pristina       PRN    Chair Airlines           A320     False
# 2            Pristina       PRN        Flexflight            320     False
# 3               Ohrid       OHD        Flexflight            320     False
# 4            Hurghada       HRG     Edelweiss Air           A320     False
# 5             Antalya       AYT     Edelweiss Air           A320     False
# 6              Athens       ATH  Helvetic Airways           E295     False
# 7              Lisbon       LIS  TAP Air Portugal           A20N     False
# 8               Porto       OPO             Swiss           BCS3     False
# 9            Tenerife       TFS     Edelweiss Air           A320     False
# 10       Gran Canaria       LPA     Edelweiss Air           A320     False
# 11         Marsa Alam       RMF     Edelweiss Air           A320     False
# 12             Bilbao       BIO             Swiss           A320     False
# 13      Fuerteventura       FUE     Edelweiss Air           A320     False
# 14          Lanzarote       ACE     Edelweiss Air           A320     False
# 15             Dublin       DUB             Swiss           BCS3     False
# 16             Djerba       DJE     Edelweiss Air           A320     False
# 17          Heraklion       HER     Edelweiss Air           A320     False
# 18             Skopje       SKP    Chair Airlines           A319     False
# 19  Palma de Mallorca       PMI     Edelweiss Air           A320     False
# 20           Pristina       PRN             Swiss           A320     False
# 21             Skopje       SKP        Flexflight            320     False
# 22             Warsaw       WAW  Helvetic Airways           E290     False
# 23       Thessaloniki       SKG  Helvetic Airways           E190     False
# 24  Palma de Mallorca       PMI             Swiss           A21N     False
# 25          Frankfurt       FRA  Helvetic Airways           E295     False
# 26           Belgrade       BEG             Swiss           A321     False
# 27             Madrid       MAD  Helvetic Airways           E295     False
# 28          Amsterdam       AMS               KLM           B738     False
# 29           Sarajevo       SJJ             Swiss           BCS1     False
# 30            Palermo       PMO             Swiss           A20N     False
# 31           Valencia       VLC             Swiss           BCS3     False
# 32            Palermo       PMO             Swiss           A20N     False
# 33           Sarajevo       SJJ             Swiss           BCS1     False
# 34             London       LHR             Swiss           A21N     False
# 35         Manchester       MAN  Helvetic Airways           E190     False
# 36             Tirana       TIA             Swiss           BCS3     False
# 37             Naples       NAP             Swiss           BCS3     False
# 38             London       LHR             Swiss           A21N     False
# 39         Dusseldorf       DUS  Helvetic Airways           E195     False
# 40         Copenhagen       CPH        Air Baltic           BCS3     False
# 41          Barcelona       BCN             Swiss           A321     False
# 42           Budapest       BUD             Swiss           A320     False
# 43            Hamburg       HAM             Swiss           A20N     False
# 44             Munich       MUC  Helvetic Airways           E195     False
# 45          Dubrovnik       DBV             Swiss           BCS1     False
# 46          Amsterdam       AMS  Helvetic Airways           E290     False
# 47             Berlin       BER        Air Baltic           BCS3     False
# 48             Vienna       VIE             Swiss           A321     False
# 49               Rome       FCO             Swiss           A320     False
#
#               DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0  2025-05-18 05:45:00       06:00 2025-05-18 06:00:00             15
# 1  2025-05-18 05:45:00       06:02 2025-05-18 06:02:00             17
# 2  2025-05-18 05:45:00         NaN 2025-05-18 00:00:00           -345
# 3  2025-05-18 05:45:00         NaN 2025-05-18 00:00:00           -345
# 4  2025-05-18 06:00:00       06:09 2025-05-18 06:09:00              9
# 5  2025-05-18 06:00:00       06:11 2025-05-18 06:11:00             11
# 6  2025-05-18 06:10:00       06:53 2025-05-18 06:53:00             43
# 7  2025-05-18 06:10:00       06:21 2025-05-18 06:21:00             11
# 8  2025-05-18 06:20:00       06:49 2025-05-18 06:49:00             29
# 9  2025-05-18 06:20:00       06:47 2025-05-18 06:47:00             27
# 10 2025-05-18 06:25:00       06:39 2025-05-18 06:39:00             14
# 11 2025-05-18 06:25:00       06:41 2025-05-18 06:41:00             16
# 12 2025-05-18 06:25:00       06:51 2025-05-18 06:51:00             26
# 13 2025-05-18 06:30:00       06:43 2025-05-18 06:43:00             13
# 14 2025-05-18 06:30:00       07:00 2025-05-18 07:00:00             30
# 15 2025-05-18 06:35:00       07:02 2025-05-18 07:02:00             27
# 16 2025-05-18 06:35:00       07:23 2025-05-18 07:23:00             48
# 17 2025-05-18 06:40:00       06:58 2025-05-18 06:58:00             18
# 18 2025-05-18 06:45:00       06:45 2025-05-18 06:45:00              0
# 19 2025-05-18 06:45:00       07:05 2025-05-18 07:05:00             20
# 20 2025-05-18 06:45:00       06:56 2025-05-18 06:56:00             11
# 21 2025-05-18 06:45:00         NaN 2025-05-18 00:00:00           -405
# 22 2025-05-18 06:50:00       07:11 2025-05-18 07:11:00             21
# 23 2025-05-18 06:50:00       07:04 2025-05-18 07:04:00             14
# 24 2025-05-18 06:50:00       07:08 2025-05-18 07:08:00             18
# 25 2025-05-18 06:55:00       07:10 2025-05-18 07:10:00             15
# 26 2025-05-18 06:55:00       07:15 2025-05-18 07:15:00             20
# 27 2025-05-18 06:55:00       07:16 2025-05-18 07:16:00             21
# 28 2025-05-18 07:00:00       07:23 2025-05-18 07:23:00             23
# 29 2025-05-18 07:00:00       07:17 2025-05-18 07:17:00             17
# 30 2025-05-18 07:00:00         NaN 2025-05-18 00:00:00           -420
# 31 2025-05-18 07:00:00       07:18 2025-05-18 07:18:00             18
# 32 2025-05-18 07:00:00       07:12 2025-05-18 07:12:00             12
# 33 2025-05-18 07:00:00       09:31 2025-05-18 09:31:00            151
# 34 2025-05-18 07:05:00       07:21 2025-05-18 07:21:00             16
# 35 2025-05-18 07:05:00       07:41 2025-05-18 07:41:00             36
# 36 2025-05-18 07:05:00       07:13 2025-05-18 07:13:00              8
# 37 2025-05-18 07:05:00       07:20 2025-05-18 07:20:00             15
# 38 2025-05-18 07:05:00         NaN 2025-05-18 00:00:00           -425
# 39 2025-05-18 07:10:00       07:28 2025-05-18 07:28:00             18
# 40 2025-05-18 07:10:00       07:26 2025-05-18 07:26:00             16
# 41 2025-05-18 07:10:00       07:26 2025-05-18 07:26:00             16
# 42 2025-05-18 07:10:00       07:31 2025-05-18 07:31:00             21
# 43 2025-05-18 07:15:00       07:34 2025-05-18 07:34:00             19
# 44 2025-05-18 07:15:00       07:39 2025-05-18 07:39:00             24
# 45 2025-05-18 07:15:00       07:36 2025-05-18 07:36:00             21
# 46 2025-05-18 07:20:00       07:45 2025-05-18 07:45:00             25
# 47 2025-05-18 07:20:00       07:42 2025-05-18 07:42:00             22
# 48 2025-05-18 07:20:00       07:40 2025-05-18 07:40:00             20
# 49 2025-05-18 07:20:00       07:34 2025-05-18 07:34:00             14
#
#
# DESTINATION_CLEAN            object
# IATA_CODE                    object
# AIRLINE_CLEAN                object
# AIRCRAFT_SHORT               object
# CANCELED                       bool
# DATETIME             datetime64[ns]
# DEPART_TIME                  object
# DEPART_DATETIME      datetime64[ns]
# DELAY_MINUTES                 int64
# dtype: object
# (387, 9)

# %% [markdown]
# ## Count missing values in columns

# %%
# Count missing values per column
print(flightradar_clean.isnull().sum())

# Total number of missing values in the DataFrame
print("Total missing values:", flightradar_clean.isnull().sum().sum())
# Out:
# DESTINATION_CLEAN     0
# IATA_CODE             0
# AIRLINE_CLEAN         7
# AIRCRAFT_SHORT        0
# CANCELED              0
# DATETIME              0
# DEPART_TIME          13
# DEPART_DATETIME       0
# DELAY_MINUTES         0
# dtype: int64
# Total missing values: 20

# %% [markdown]
# ## Show rows with missing values in the DataFrame

# %%
# Filter rows with any missing values
missing_rows = flightradar_clean[flightradar_clean.isnull().any(axis=1)]

# Display rows with missing values
print(missing_rows)
# Out:
#      DESTINATION_CLEAN IATA_CODE    AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 2             Pristina       PRN       Flexflight            320     False
# 3                Ohrid       OHD       Flexflight            320     False
# 21              Skopje       SKP       Flexflight            320     False
# 30             Palermo       PMO            Swiss           A20N     False
# 38              London       LHR            Swiss           A21N     False
# 55          Manchester       MAN              NaN           GL5T     False
# 63            Pristina       PRN      GP Aviation            734     False
# 81             Rostock       RLG     euroairlines            738     False
# 123           Hurghada       HRG       Flexflight            320     False
# 127  Palma de Mallorca       PMI       Flexflight            320     False
# 128          Groningen       GRQ              NaN           SF50     False
# 131               Rome       CIA              NaN           C25A     False
# 209             Geneva       GVA              NaN           GLEX     False
# 216                Kos       KGS       Flexflight            319     False
# 217              Tivat       TIV              NaN           M600     False
# 275           Pristina       PRN       Flexflight            320     False
# 327             London       LHR  British Airways           A319     False
# 331           Grenchen       QYG              NaN           PC12     False
# 356               Oslo       OSL              NaN           BE20     False
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 2   2025-05-18 05:45:00         NaN 2025-05-18 00:00:00           -345
# 3   2025-05-18 05:45:00         NaN 2025-05-18 00:00:00           -345
# 21  2025-05-18 06:45:00         NaN 2025-05-18 00:00:00           -405
# 30  2025-05-18 07:00:00         NaN 2025-05-18 00:00:00           -420
# 38  2025-05-18 07:05:00         NaN 2025-05-18 00:00:00           -425
# 55  2025-05-18 07:30:00       07:39 2025-05-18 07:39:00              9
# 63  2025-05-18 08:20:00         NaN 2025-05-18 00:00:00           -500
# 81  2025-05-18 09:20:00         NaN 2025-05-18 00:00:00           -560
# 123 2025-05-18 11:15:00         NaN 2025-05-18 00:00:00           -675
# 127 2025-05-18 11:30:00         NaN 2025-05-18 00:00:00           -690
# 128 2025-05-18 11:30:00       11:33 2025-05-18 11:33:00              3
# 131 2025-05-18 11:40:00       11:40 2025-05-18 11:40:00              0
# 209 2025-05-18 13:40:00       14:24 2025-05-18 14:24:00             44
# 216 2025-05-18 14:00:00         NaN 2025-05-18 00:00:00           -840
# 217 2025-05-18 14:00:00       14:34 2025-05-18 14:34:00             34
# 275 2025-05-18 17:15:00         NaN 2025-05-18 00:00:00          -1035
# 327 2025-05-18 19:40:00         NaN 2025-05-18 00:00:00          -1180
# 331 2025-05-18 19:45:00       19:46 2025-05-18 19:46:00              1
# 356 2025-05-18 21:00:00         NaN 2025-05-18 00:00:00          -1260

# %% [markdown]
# ## Show the DataFrame without missing values

# %%
# Drop rows with any missing values (NaN)
flightradar_clean = flightradar_clean.dropna(axis=0)

# Display the DataFrame after dropping rows with missing values
print(flightradar_clean)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0               Ohrid       OHD    Chair Airlines           A320     False
# 1            Pristina       PRN    Chair Airlines           A320     False
# 4            Hurghada       HRG     Edelweiss Air           A320     False
# 5             Antalya       AYT     Edelweiss Air           A320     False
# 6              Athens       ATH  Helvetic Airways           E295     False
# ..                ...       ...               ...            ...       ...
# 382         Sao Paulo       GRU             Swiss           B77W     False
# 383         Singapore       SIN             Swiss           B77W     False
# 384         Hong Kong       HKG             Swiss           B77W     False
# 385             Milan       MXP  Helvetic Airways           E190     False
# 386      Johannesburg       JNB             Swiss           A343     False
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0   2025-05-18 05:45:00       06:00 2025-05-18 06:00:00             15
# 1   2025-05-18 05:45:00       06:02 2025-05-18 06:02:00             17
# 4   2025-05-18 06:00:00       06:09 2025-05-18 06:09:00              9
# 5   2025-05-18 06:00:00       06:11 2025-05-18 06:11:00             11
# 6   2025-05-18 06:10:00       06:53 2025-05-18 06:53:00             43
# ..                  ...         ...                 ...            ...
# 382 2025-05-18 22:40:00       22:57 2025-05-18 22:57:00             17
# 383 2025-05-18 22:40:00       22:51 2025-05-18 22:51:00             11
# 384 2025-05-18 22:40:00       22:48 2025-05-18 22:48:00              8
# 385 2025-05-18 22:40:00       22:50 2025-05-18 22:50:00             10
# 386 2025-05-18 22:40:00       22:59 2025-05-18 22:59:00             19
#
# [368 rows x 9 columns]

# %% [markdown]
# ## Check for duplicate rows in the DataFrame and display them if any exist

# %%
# Duplikate prüfen
duplicates = flightradar_clean[flightradar_clean.duplicated()]

# Duplikate anzeigen (falls vorhanden)
print(duplicates)

# Anzahl der Duplikate
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [DESTINATION_CLEAN, IATA_CODE, AIRLINE_CLEAN, AIRCRAFT_SHORT, CANCELED, DATETIME, DEPART_TIME, DEPART_DATETIME, DELAY_MINUTES]
# Index: []
# Number of duplicate rows: 0

# %% [markdown]
# ## Save the cleaned DataFrame to a CSV file for further use or analysis

# %%
# Speichern des DataFrames als CSV-Datei
flightradar_clean.to_csv("prepared/250518_flightradar_prepared.csv", index=False)
