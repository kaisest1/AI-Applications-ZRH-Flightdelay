# %% [markdown]
# # Data preparation
# ## Read and show Excel data for one day from Flightradar

# %%
import pandas as pd

# %%
# XLSX-Datei laden
flightradar = pd.read_excel("250505_flightradar.xlsx")

# Erste 5 Zeilen anzeigen
print(flightradar.head(5))
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1746512368-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1746512368-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1746512368-3  https://www.flightradar24.com/data/airports/zr...   NaN
# 3      1746512368-4  https://www.flightradar24.com/data/airports/zr...   NaN
# 4      1746512368-5  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  FLIGHT  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   WK370
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  W22160
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   CS600
# 3    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK134
# 4    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK348
#
#         DESTINATION           AIRLINE       AIRCRAFT          STATUS
# 0    Larnaca (LCA)-   Edelweiss Air -  A320 (HB-IJV)  Departed 06:09
# 1   Pristina (PRN)-      Flexflight -         320 ()         Unknown
# 2   Pristina (PRN)-  Chair Airlines -  A320 (HB-JOS)  Departed 06:00
# 3   Hurghada (HRG)-   Edelweiss Air -  A320 (HB-JJM)  Departed 06:07
# 4  Heraklion (HER)-   Edelweiss Air -  A320 (HB-JLR)  Departed 06:12

# %% [markdown]
# ## Show data types and shape of the DataFrame

# %%
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# dtype: object
# (390, 15)

# %% [markdown]
# ## The Date is missing in the DataFrame. Create a new field DATETIME
# ### DATETIME is the planned departure time for that day

# %%
# Datum als Variable definieren
date_str = "2025-05-05"

# %%
# TIME als String sicherstellen (falls es z. B. float ist)
flightradar["TIME"] = flightradar["TIME"].astype(str)

# DATETIME-Feld erzeugen: 'date_str' + Zeit aus TIME-Feld
flightradar["DATETIME"] = date_str + " " + flightradar["TIME"]

# Kontrolle
print(flightradar[["TIME", "DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#         TIME             DATETIME
# 0   05:45:00  2025-05-05 05:45:00
# 1   05:45:00  2025-05-05 05:45:00
# 2   05:45:00  2025-05-05 05:45:00
# 3   06:00:00  2025-05-05 06:00:00
# 4   06:00:00  2025-05-05 06:00:00
# 5   06:10:00  2025-05-05 06:10:00
# 6   06:10:00  2025-05-05 06:10:00
# 7   06:20:00  2025-05-05 06:20:00
# 8   06:20:00  2025-05-05 06:20:00
# 9   06:25:00  2025-05-05 06:25:00
# 10  06:25:00  2025-05-05 06:25:00
# 11  06:30:00  2025-05-05 06:30:00
# 12  06:40:00  2025-05-05 06:40:00
# 13  06:45:00  2025-05-05 06:45:00
# 14  06:45:00  2025-05-05 06:45:00
# 15  06:45:00  2025-05-05 06:45:00
# 16  06:45:00  2025-05-05 06:45:00
# 17  06:45:00  2025-05-05 06:45:00
# 18  06:50:00  2025-05-05 06:50:00
# 19  06:50:00  2025-05-05 06:50:00
# 20  06:55:00  2025-05-05 06:55:00
# 21  06:55:00  2025-05-05 06:55:00
# 22  06:55:00  2025-05-05 06:55:00
# 23  06:55:00  2025-05-05 06:55:00
# 24  07:00:00  2025-05-05 07:00:00
# 25  07:00:00  2025-05-05 07:00:00
# 26  07:05:00  2025-05-05 07:05:00
# 27  07:05:00  2025-05-05 07:05:00
# 28  07:05:00  2025-05-05 07:05:00
# 29  07:05:00  2025-05-05 07:05:00
# 30  07:05:00  2025-05-05 07:05:00
# 31  07:10:00  2025-05-05 07:10:00
# 32  07:10:00  2025-05-05 07:10:00
# 33  07:10:00  2025-05-05 07:10:00
# 34  07:10:00  2025-05-05 07:10:00
# 35  07:15:00  2025-05-05 07:15:00
# 36  07:15:00  2025-05-05 07:15:00
# 37  07:15:00  2025-05-05 07:15:00
# 38  07:20:00  2025-05-05 07:20:00
# 39  07:20:00  2025-05-05 07:20:00
# 40  07:20:00  2025-05-05 07:20:00
# 41  07:20:00  2025-05-05 07:20:00
# 42  07:25:00  2025-05-05 07:25:00
# 43  07:25:00  2025-05-05 07:25:00
# 44  07:25:00  2025-05-05 07:25:00
# 45  07:30:00  2025-05-05 07:30:00
# 46  07:30:00  2025-05-05 07:30:00
# 47  07:30:00  2025-05-05 07:30:00
# 48  07:30:00  2025-05-05 07:30:00
# 49  07:35:00  2025-05-05 07:35:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# dtype: object
# (390, 16)

# %% [markdown]
# ## Create two new fields: DESTINATION_CLEAN and IATA_CODE using regex

# %%
# DESTINATION_CLEAN: Alles vor der Klammer
flightradar["DESTINATION_CLEAN"] = flightradar["DESTINATION"].str.extract(r"^(.*?)\s*\(")

# IATA-CODE: Inhalt in der Klammer
flightradar["IATA_CODE"] = flightradar["DESTINATION"].str.extract(r"\((\w{3})\)")

# Kontrolle
print(flightradar[["DESTINATION", "DESTINATION_CLEAN", "IATA_CODE"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                  DESTINATION  DESTINATION_CLEAN IATA_CODE
# 0             Larnaca (LCA)-            Larnaca       LCA
# 1            Pristina (PRN)-           Pristina       PRN
# 2            Pristina (PRN)-           Pristina       PRN
# 3            Hurghada (HRG)-           Hurghada       HRG
# 4           Heraklion (HER)-          Heraklion       HER
# 5             Antalya (AYT)-            Antalya       AYT
# 6        Gran Canaria (LPA)-       Gran Canaria       LPA
# 7              Lisbon (LIS)-             Lisbon       LIS
# 8            Tenerife (TFS)-           Tenerife       TFS
# 9           Marrakesh (RAK)-          Marrakesh       RAK
# 10              Olbia (OLB)-              Olbia       OLB
# 11           Pristina (PRN)-           Pristina       PRN
# 12              Ibiza (IBZ)-              Ibiza       IBZ
# 13             Bilbao (BIO)-             Bilbao       BIO
# 14            Funchal (FNC)-            Funchal       FNC
# 15           Hurghada (HRG)-           Hurghada       HRG
# 16           Hurghada (HRG)-           Hurghada       HRG
# 17              Split (SPU)-              Split       SPU
# 18           Brindisi (BDS)-           Brindisi       BDS
# 19  Palma de Mallorca (PMI)-  Palma de Mallorca       PMI
# 20          Frankfurt (FRA)-          Frankfurt       FRA
# 21             Krakow (KRK)-             Krakow       KRK
# 22           Belgrade (BEG)-           Belgrade       BEG
# 23             Madrid (MAD)-             Madrid       MAD
# 24          Amsterdam (AMS)-          Amsterdam       AMS
# 25         Birmingham (BHX)-         Birmingham       BHX
# 26             London (LHR)-             London       LHR
# 27         Manchester (MAN)-         Manchester       MAN
# 28             Warsaw (WAW)-             Warsaw       WAW
# 29             Naples (NAP)-             Naples       NAP
# 30             London (LHR)-             London       LHR
# 31         Gothenburg (GOT)-         Gothenburg       GOT
# 32         Copenhagen (CPH)-         Copenhagen       CPH
# 33           Budapest (BUD)-           Budapest       BUD
# 34          Barcelona (BCN)-          Barcelona       BCN
# 35             London (LHR)-             London       LHR
# 36            Hamburg (HAM)-            Hamburg       HAM
# 37             Munich (MUC)-             Munich       MUC
# 38          Amsterdam (AMS)-          Amsterdam       AMS
# 39             Berlin (BER)-             Berlin       BER
# 40             Vienna (VIE)-             Vienna       VIE
# 41               Rome (FCO)-               Rome       FCO
# 42           Brussels (BRU)-           Brussels       BRU
# 43              Paris (CDG)-              Paris       CDG
# 44             Geneva (GVA)-             Geneva       GVA
# 45             Madrid (MAD)-             Madrid       MAD
# 46               Nice (NCE)-               Nice       NCE
# 47         Dusseldorf (DUS)-         Dusseldorf       DUS
# 48      Ponta Delgada (PDL)-      Ponta Delgada       PDL
# 49            Dresden (DRS)-            Dresden       DRS
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# dtype: object
# (390, 18)

# %% [markdown]
# ## Create three new fields: CANCELED, DEPART_TIME and DEPART_DATETIME using regex

# %%
# 1. CANCELED-Spalte (Boolean)
flightradar["CANCELED"] = flightradar["STATUS"].str.contains("Canceled", na=False)

# 2. DEPART_TIME-Spalte (nur wenn "Departed HH:MM" enthalten ist)
flightradar["DEPART_TIME"] = flightradar["STATUS"].str.extract(r"Departed\s*(\d{2}:\d{2})")[0]

# 3. DEPART_DATETIME-Spalte: date_str + DEPART_TIME (fallback "00:00") + ":00"
flightradar["DEPART_DATETIME"] = (
    date_str
    + " "
    + flightradar["DEPART_TIME"].fillna("00:00") # falls keine Zeit da ist, setze "00:00"
    + ":00" # Sekunden anhängen
)

# Kontrolle
print(flightradar[["STATUS","CANCELED","DEPART_TIME","DEPART_DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                    STATUS  CANCELED DEPART_TIME      DEPART_DATETIME
# 0          Departed 06:09     False       06:09  2025-05-05 06:09:00
# 1                 Unknown     False         NaN  2025-05-05 00:00:00
# 2          Departed 06:00     False       06:00  2025-05-05 06:00:00
# 3          Departed 06:07     False       06:07  2025-05-05 06:07:00
# 4          Departed 06:12     False       06:12  2025-05-05 06:12:00
# 5          Departed 06:21     False       06:21  2025-05-05 06:21:00
# 6          Departed 06:18     False       06:18  2025-05-05 06:18:00
# 7          Departed 06:48     False       06:48  2025-05-05 06:48:00
# 8          Departed 06:30     False       06:30  2025-05-05 06:30:00
# 9          Departed 06:33     False       06:33  2025-05-05 06:33:00
# 10         Departed 06:36     False       06:36  2025-05-05 06:36:00
# 11         Departed 06:42     False       06:42  2025-05-05 06:42:00
# 12         Departed 07:00     False       07:00  2025-05-05 07:00:00
# 13         Departed 06:57     False       06:57  2025-05-05 06:57:00
# 14         Departed 07:17     False       07:17  2025-05-05 07:17:00
# 15                Unknown     False         NaN  2025-05-05 00:00:00
# 16         Departed 06:55     False       06:55  2025-05-05 06:55:00
# 17         Departed 07:01     False       07:01  2025-05-05 07:01:00
# 18         Departed 06:53     False       06:53  2025-05-05 06:53:00
# 19         Departed 07:06     False       07:06  2025-05-05 07:06:00
# 20         Departed 07:04     False       07:04  2025-05-05 07:04:00
# 21         Departed 07:13     False       07:13  2025-05-05 07:13:00
# 22         Departed 07:15     False       07:15  2025-05-05 07:15:00
# 23         Departed 07:21     False       07:21  2025-05-05 07:21:00
# 24         Departed 07:36     False       07:36  2025-05-05 07:36:00
# 25         Departed 07:33     False       07:33  2025-05-05 07:33:00
# 26         Departed 07:26     False       07:26  2025-05-05 07:26:00
# 27         Departed 07:23     False       07:23  2025-05-05 07:23:00
# 28         Departed 07:34     False       07:34  2025-05-05 07:34:00
# 29         Departed 07:19     False       07:19  2025-05-05 07:19:00
# 30  Estimated dep.  07:27     False         NaN  2025-05-05 00:00:00
# 31         Departed 07:29     False       07:29  2025-05-05 07:29:00
# 32         Departed 07:31     False       07:31  2025-05-05 07:31:00
# 33         Departed 07:41     False       07:41  2025-05-05 07:41:00
# 34         Departed 07:43     False       07:43  2025-05-05 07:43:00
# 35         Departed 07:52     False       07:52  2025-05-05 07:52:00
# 36         Departed 07:37     False       07:37  2025-05-05 07:37:00
# 37         Departed 08:00     False       08:00  2025-05-05 08:00:00
# 38         Departed 07:56     False       07:56  2025-05-05 07:56:00
# 39         Departed 07:47     False       07:47  2025-05-05 07:47:00
# 40         Departed 07:39     False       07:39  2025-05-05 07:39:00
# 41         Departed 07:46     False       07:46  2025-05-05 07:46:00
# 42         Departed 07:49     False       07:49  2025-05-05 07:49:00
# 43         Departed 08:14     False       08:14  2025-05-05 08:14:00
# 44         Departed 08:04     False       08:04  2025-05-05 08:04:00
# 45         Departed 07:44     False       07:44  2025-05-05 07:44:00
# 46         Departed 08:07     False       08:07  2025-05-05 08:07:00
# 47         Departed 07:58     False       07:58  2025-05-05 07:58:00
# 48         Departed 07:54     False       07:54  2025-05-05 07:54:00
# 49         Departed 08:05     False       08:05  2025-05-05 08:05:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# dtype: object
# (390, 21)

# %% [markdown]
# ## Creating the AIRLINE_CLEAN field and removing unimportant parts

# %%
flightradar["AIRLINE_CLEAN"] = (
    flightradar["AIRLINE"]
      .str.extract(r'^(.+?)(?=\s*(?:\(|-))')[0]  # Gruppe 1: alles bis vor "(" oder "-"
      .str.strip()                               # führende/trailing Leerzeichen entfernen
)

# Kontrolle
print(flightradar[["AIRLINE","AIRLINE_CLEAN"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                                       AIRLINE     AIRLINE_CLEAN
# 0                             Edelweiss Air -     Edelweiss Air
# 1                                Flexflight -        Flexflight
# 2                            Chair Airlines -    Chair Airlines
# 3                             Edelweiss Air -     Edelweiss Air
# 4                             Edelweiss Air -     Edelweiss Air
# 5      Edelweiss Air (Help Alliance Livery) -     Edelweiss Air
# 6                             Edelweiss Air -     Edelweiss Air
# 7                          TAP Air Portugal -  TAP Air Portugal
# 8                             Edelweiss Air -     Edelweiss Air
# 9                             Edelweiss Air -     Edelweiss Air
# 10                            Edelweiss Air -     Edelweiss Air
# 11                            Edelweiss Air -     Edelweiss Air
# 12                                 Aeroways -          Aeroways
# 13                            Edelweiss Air -     Edelweiss Air
# 14                            Edelweiss Air -     Edelweiss Air
# 15                               Flexflight -        Flexflight
# 16                           Chair Airlines -    Chair Airlines
# 17                           NetJets Europe -    NetJets Europe
# 18                                    Swiss -             Swiss
# 19             Swiss (Star Alliance Livery) -             Swiss
# 20                         Helvetic Airways -  Helvetic Airways
# 21                                    Swiss -             Swiss
# 22                                    Swiss -             Swiss
# 23                                    Swiss -             Swiss
# 24                                      KLM -               KLM
# 25                         Helvetic Airways -  Helvetic Airways
# 26                                    Swiss -             Swiss
# 27                         Helvetic Airways -  Helvetic Airways
# 28                                    Swiss -             Swiss
# 29                                    Swiss -             Swiss
# 30                                    Swiss -             Swiss
# 31  Helvetic Airways (1600th E-jet sticker) -  Helvetic Airways
# 32                               Air Baltic -        Air Baltic
# 33                               Air Baltic -        Air Baltic
# 34                                    Swiss -             Swiss
# 35                          British Airways -   British Airways
# 36                                    Swiss -             Swiss
# 37                         Helvetic Airways -  Helvetic Airways
# 38             Swiss (Star Alliance Livery) -             Swiss
# 39                                    Swiss -             Swiss
# 40                                    Swiss -             Swiss
# 41                                    Swiss -             Swiss
# 42                                    Swiss -             Swiss
# 43                                    Swiss -             Swiss
# 44                                    Swiss -             Swiss
# 45                                   Iberia -            Iberia
# 46                                    Swiss -             Swiss
# 47                         Helvetic Airways -  Helvetic Airways
# 48                            Edelweiss Air -     Edelweiss Air
# 49                         Helvetic Airways -  Helvetic Airways
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# dtype: object
# (390, 22)

# %% [markdown]
# ## Creating the AIRCRAFT_SHORT field

# %%
# Create the AIRCRAFT_SHORT field by removing text inside parentheses
flightradar["AIRCRAFT_SHORT"] = (
    flightradar["AIRCRAFT"]
      .str.replace(r"\s*\(.*?\)", "", regex=True)  # non‑greedy, regex=True
      .str.strip()
)

# Check the result
print(flightradar[["AIRCRAFT", "AIRCRAFT_SHORT"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#          AIRCRAFT AIRCRAFT_SHORT
# 0   A320 (HB-IJV)           A320
# 1          320 ()            320
# 2   A320 (HB-JOS)           A320
# 3   A320 (HB-JJM)           A320
# 4   A320 (HB-JLR)           A320
# 5   A320 (HB-JLT)           A320
# 6   A320 (HB-IHX)           A320
# 7   A321 (CS-TJF)           A321
# 8   A320 (HB-JLP)           A320
# 9   A320 (HB-JJK)           A320
# 10  A320 (HB-IHY)           A320
# 11  A359 (HB-IHF)           A359
# 12  C25A (D-IBRN)           C25A
# 13  A320 (HB-JLS)           A320
# 14  A320 (HB-JJN)           A320
# 15         320 ()            320
# 16  A320 (HB-JOK)           A320
# 17  C56X (CS-DXO)           C56X
# 18  A320 (HB-IJJ)           A320
# 19  A320 (HB-IJM)           A320
# 20  E295 (HB-AZK)           E295
# 21  BCS3 (HB-JCU)           BCS3
# 22  BCS1 (HB-JBH)           BCS1
# 23  BCS3 (HB-JCT)           BCS3
# 24  B738 (PH-BCK)           B738
# 25  E290 (HB-AZC)           E290
# 26  A20N (HB-JDH)           A20N
# 27  E290 (HB-AZA)           E290
# 28  BCS1 (HB-JBE)           BCS1
# 29  A320 (HB-IJI)           A320
# 30  A20N (HB-JDH)           A20N
# 31  E290 (HB-AZE)           E290
# 32  BCS3 (YL-ABP)           BCS3
# 33  BCS3 (YL-AAW)           BCS3
# 34  A21N (HB-JPA)           A21N
# 35  A320 (G-EUYO)           A320
# 36  BCS3 (HB-JCE)           BCS3
# 37  E295 (HB-AZI)           E295
# 38  A320 (HB-IJO)           A320
# 39  A321 (HB-IOF)           A321
# 40  BCS3 (HB-JCK)           BCS3
# 41  A321 (HB-IOO)           A321
# 42  A21N (HB-JPD)           A21N
# 43  A320 (HB-IJL)           A320
# 44  A321 (HB-IOM)           A321
# 45  A20N (EC-NVS)           A20N
# 46  BCS1 (HB-JBC)           BCS1
# 47  E195 (HB-JVW)           E195
# 48  A320 (HB-IHZ)           A320
# 49  E190 (HB-JVN)           E190
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# AIRCRAFT_SHORT            object
# dtype: object
# (390, 23)

# %% [markdown]
# ## Create a new field DELAY and DELAY_MINUTES and calculate it from DATETIME and DEPART_DATETIME

# %%
# 1) Stelle sicher, dass beide Spalten als datetime64 vorliegen
flightradar["DATETIME"] = pd.to_datetime(flightradar["DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")
flightradar["DEPART_DATETIME"] = pd.to_datetime(flightradar["DEPART_DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")

# 2) DELAY als Differenz berechnen
flightradar["DELAY"] = flightradar["DEPART_DATETIME"] - flightradar["DATETIME"]

# 3a) Variante A: Floor‑Division auf total_seconds, dann in int
flightradar["DELAY_MINUTES"] = (
    flightradar["DELAY"].dt.total_seconds() // 60
).astype(int)

# Kontrolle
print(flightradar[["DATETIME","DEPART_DATETIME","DELAY","DELAY_MINUTES"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#               DATETIME     DEPART_DATETIME             DELAY  DELAY_MINUTES
# 0  2025-05-05 05:45:00 2025-05-05 06:09:00   0 days 00:24:00             24
# 1  2025-05-05 05:45:00 2025-05-05 00:00:00 -1 days +18:15:00           -345
# 2  2025-05-05 05:45:00 2025-05-05 06:00:00   0 days 00:15:00             15
# 3  2025-05-05 06:00:00 2025-05-05 06:07:00   0 days 00:07:00              7
# 4  2025-05-05 06:00:00 2025-05-05 06:12:00   0 days 00:12:00             12
# 5  2025-05-05 06:10:00 2025-05-05 06:21:00   0 days 00:11:00             11
# 6  2025-05-05 06:10:00 2025-05-05 06:18:00   0 days 00:08:00              8
# 7  2025-05-05 06:20:00 2025-05-05 06:48:00   0 days 00:28:00             28
# 8  2025-05-05 06:20:00 2025-05-05 06:30:00   0 days 00:10:00             10
# 9  2025-05-05 06:25:00 2025-05-05 06:33:00   0 days 00:08:00              8
# 10 2025-05-05 06:25:00 2025-05-05 06:36:00   0 days 00:11:00             11
# 11 2025-05-05 06:30:00 2025-05-05 06:42:00   0 days 00:12:00             12
# 12 2025-05-05 06:40:00 2025-05-05 07:00:00   0 days 00:20:00             20
# 13 2025-05-05 06:45:00 2025-05-05 06:57:00   0 days 00:12:00             12
# 14 2025-05-05 06:45:00 2025-05-05 07:17:00   0 days 00:32:00             32
# 15 2025-05-05 06:45:00 2025-05-05 00:00:00 -1 days +17:15:00           -405
# 16 2025-05-05 06:45:00 2025-05-05 06:55:00   0 days 00:10:00             10
# 17 2025-05-05 06:45:00 2025-05-05 07:01:00   0 days 00:16:00             16
# 18 2025-05-05 06:50:00 2025-05-05 06:53:00   0 days 00:03:00              3
# 19 2025-05-05 06:50:00 2025-05-05 07:06:00   0 days 00:16:00             16
# 20 2025-05-05 06:55:00 2025-05-05 07:04:00   0 days 00:09:00              9
# 21 2025-05-05 06:55:00 2025-05-05 07:13:00   0 days 00:18:00             18
# 22 2025-05-05 06:55:00 2025-05-05 07:15:00   0 days 00:20:00             20
# 23 2025-05-05 06:55:00 2025-05-05 07:21:00   0 days 00:26:00             26
# 24 2025-05-05 07:00:00 2025-05-05 07:36:00   0 days 00:36:00             36
# 25 2025-05-05 07:00:00 2025-05-05 07:33:00   0 days 00:33:00             33
# 26 2025-05-05 07:05:00 2025-05-05 07:26:00   0 days 00:21:00             21
# 27 2025-05-05 07:05:00 2025-05-05 07:23:00   0 days 00:18:00             18
# 28 2025-05-05 07:05:00 2025-05-05 07:34:00   0 days 00:29:00             29
# 29 2025-05-05 07:05:00 2025-05-05 07:19:00   0 days 00:14:00             14
# 30 2025-05-05 07:05:00 2025-05-05 00:00:00 -1 days +16:55:00           -425
# 31 2025-05-05 07:10:00 2025-05-05 07:29:00   0 days 00:19:00             19
# 32 2025-05-05 07:10:00 2025-05-05 07:31:00   0 days 00:21:00             21
# 33 2025-05-05 07:10:00 2025-05-05 07:41:00   0 days 00:31:00             31
# 34 2025-05-05 07:10:00 2025-05-05 07:43:00   0 days 00:33:00             33
# 35 2025-05-05 07:15:00 2025-05-05 07:52:00   0 days 00:37:00             37
# 36 2025-05-05 07:15:00 2025-05-05 07:37:00   0 days 00:22:00             22
# 37 2025-05-05 07:15:00 2025-05-05 08:00:00   0 days 00:45:00             45
# 38 2025-05-05 07:20:00 2025-05-05 07:56:00   0 days 00:36:00             36
# 39 2025-05-05 07:20:00 2025-05-05 07:47:00   0 days 00:27:00             27
# 40 2025-05-05 07:20:00 2025-05-05 07:39:00   0 days 00:19:00             19
# 41 2025-05-05 07:20:00 2025-05-05 07:46:00   0 days 00:26:00             26
# 42 2025-05-05 07:25:00 2025-05-05 07:49:00   0 days 00:24:00             24
# 43 2025-05-05 07:25:00 2025-05-05 08:14:00   0 days 00:49:00             49
# 44 2025-05-05 07:25:00 2025-05-05 08:04:00   0 days 00:39:00             39
# 45 2025-05-05 07:30:00 2025-05-05 07:44:00   0 days 00:14:00             14
# 46 2025-05-05 07:30:00 2025-05-05 08:07:00   0 days 00:37:00             37
# 47 2025-05-05 07:30:00 2025-05-05 07:58:00   0 days 00:28:00             28
# 48 2025-05-05 07:30:00 2025-05-05 07:54:00   0 days 00:24:00             24
# 49 2025-05-05 07:35:00 2025-05-05 08:05:00   0 days 00:30:00             30
#
#
# web-scraper-order                 object
# web-scraper-start-url             object
# page                             float64
# page2                            float64
# page3                            float64
# page4                            float64
# page5                            float64
# page6                            float64
# page7                            float64
# TIME                              object
# FLIGHT                            object
# DESTINATION                       object
# AIRLINE                           object
# AIRCRAFT                          object
# STATUS                            object
# DATETIME                  datetime64[ns]
# DESTINATION_CLEAN                 object
# IATA_CODE                         object
# CANCELED                            bool
# DEPART_TIME                       object
# DEPART_DATETIME           datetime64[ns]
# AIRLINE_CLEAN                     object
# AIRCRAFT_SHORT                    object
# DELAY                    timedelta64[ns]
# DELAY_MINUTES                      int64
# dtype: object
# (390, 25)

# %% [markdown]
# ## Showing full DataFrame

# %%
flightradar.head(3)
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1746512368-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1746512368-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1746512368-3  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  ...  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
#
#              DATETIME DESTINATION_CLEAN IATA_CODE CANCELED DEPART_TIME  \
# 0 2025-05-05 05:45:00           Larnaca       LCA    False       06:09
# 1 2025-05-05 05:45:00          Pristina       PRN    False         NaN
# 2 2025-05-05 05:45:00          Pristina       PRN    False       06:00
#
#       DEPART_DATETIME   AIRLINE_CLEAN AIRCRAFT_SHORT             DELAY  \
# 0 2025-05-05 06:09:00   Edelweiss Air           A320   0 days 00:24:00
# 1 2025-05-05 00:00:00      Flexflight            320 -1 days +18:15:00
# 2 2025-05-05 06:00:00  Chair Airlines           A320   0 days 00:15:00
#
#   DELAY_MINUTES
# 0            24
# 1          -345
# 2            15
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Creating a New DataFrame with Selected Columns

# %%
# Create a new DataFrame with selected columns
flightradar_clean = flightradar[[
    "DESTINATION_CLEAN", 
    "IATA_CODE", 
    "AIRLINE_CLEAN", 
    "AIRCRAFT_SHORT", 
    "CANCELED", 
    "DATETIME",
    "DEPART_TIME", 
    "DEPART_DATETIME", 
    "DELAY_MINUTES"
]].copy()

# Check the result
print(flightradar_clean.head(50))
print("\n")
print(flightradar_clean.dtypes)
print(flightradar_clean.shape)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Larnaca       LCA     Edelweiss Air           A320     False
# 1            Pristina       PRN        Flexflight            320     False
# 2            Pristina       PRN    Chair Airlines           A320     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4           Heraklion       HER     Edelweiss Air           A320     False
# 5             Antalya       AYT     Edelweiss Air           A320     False
# 6        Gran Canaria       LPA     Edelweiss Air           A320     False
# 7              Lisbon       LIS  TAP Air Portugal           A321     False
# 8            Tenerife       TFS     Edelweiss Air           A320     False
# 9           Marrakesh       RAK     Edelweiss Air           A320     False
# 10              Olbia       OLB     Edelweiss Air           A320     False
# 11           Pristina       PRN     Edelweiss Air           A359     False
# 12              Ibiza       IBZ          Aeroways           C25A     False
# 13             Bilbao       BIO     Edelweiss Air           A320     False
# 14            Funchal       FNC     Edelweiss Air           A320     False
# 15           Hurghada       HRG        Flexflight            320     False
# 16           Hurghada       HRG    Chair Airlines           A320     False
# 17              Split       SPU    NetJets Europe           C56X     False
# 18           Brindisi       BDS             Swiss           A320     False
# 19  Palma de Mallorca       PMI             Swiss           A320     False
# 20          Frankfurt       FRA  Helvetic Airways           E295     False
# 21             Krakow       KRK             Swiss           BCS3     False
# 22           Belgrade       BEG             Swiss           BCS1     False
# 23             Madrid       MAD             Swiss           BCS3     False
# 24          Amsterdam       AMS               KLM           B738     False
# 25         Birmingham       BHX  Helvetic Airways           E290     False
# 26             London       LHR             Swiss           A20N     False
# 27         Manchester       MAN  Helvetic Airways           E290     False
# 28             Warsaw       WAW             Swiss           BCS1     False
# 29             Naples       NAP             Swiss           A320     False
# 30             London       LHR             Swiss           A20N     False
# 31         Gothenburg       GOT  Helvetic Airways           E290     False
# 32         Copenhagen       CPH        Air Baltic           BCS3     False
# 33           Budapest       BUD        Air Baltic           BCS3     False
# 34          Barcelona       BCN             Swiss           A21N     False
# 35             London       LHR   British Airways           A320     False
# 36            Hamburg       HAM             Swiss           BCS3     False
# 37             Munich       MUC  Helvetic Airways           E295     False
# 38          Amsterdam       AMS             Swiss           A320     False
# 39             Berlin       BER             Swiss           A321     False
# 40             Vienna       VIE             Swiss           BCS3     False
# 41               Rome       FCO             Swiss           A321     False
# 42           Brussels       BRU             Swiss           A21N     False
# 43              Paris       CDG             Swiss           A320     False
# 44             Geneva       GVA             Swiss           A321     False
# 45             Madrid       MAD            Iberia           A20N     False
# 46               Nice       NCE             Swiss           BCS1     False
# 47         Dusseldorf       DUS  Helvetic Airways           E195     False
# 48      Ponta Delgada       PDL     Edelweiss Air           A320     False
# 49            Dresden       DRS  Helvetic Airways           E190     False
#
#               DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0  2025-05-05 05:45:00       06:09 2025-05-05 06:09:00             24
# 1  2025-05-05 05:45:00         NaN 2025-05-05 00:00:00           -345
# 2  2025-05-05 05:45:00       06:00 2025-05-05 06:00:00             15
# 3  2025-05-05 06:00:00       06:07 2025-05-05 06:07:00              7
# 4  2025-05-05 06:00:00       06:12 2025-05-05 06:12:00             12
# 5  2025-05-05 06:10:00       06:21 2025-05-05 06:21:00             11
# 6  2025-05-05 06:10:00       06:18 2025-05-05 06:18:00              8
# 7  2025-05-05 06:20:00       06:48 2025-05-05 06:48:00             28
# 8  2025-05-05 06:20:00       06:30 2025-05-05 06:30:00             10
# 9  2025-05-05 06:25:00       06:33 2025-05-05 06:33:00              8
# 10 2025-05-05 06:25:00       06:36 2025-05-05 06:36:00             11
# 11 2025-05-05 06:30:00       06:42 2025-05-05 06:42:00             12
# 12 2025-05-05 06:40:00       07:00 2025-05-05 07:00:00             20
# 13 2025-05-05 06:45:00       06:57 2025-05-05 06:57:00             12
# 14 2025-05-05 06:45:00       07:17 2025-05-05 07:17:00             32
# 15 2025-05-05 06:45:00         NaN 2025-05-05 00:00:00           -405
# 16 2025-05-05 06:45:00       06:55 2025-05-05 06:55:00             10
# 17 2025-05-05 06:45:00       07:01 2025-05-05 07:01:00             16
# 18 2025-05-05 06:50:00       06:53 2025-05-05 06:53:00              3
# 19 2025-05-05 06:50:00       07:06 2025-05-05 07:06:00             16
# 20 2025-05-05 06:55:00       07:04 2025-05-05 07:04:00              9
# 21 2025-05-05 06:55:00       07:13 2025-05-05 07:13:00             18
# 22 2025-05-05 06:55:00       07:15 2025-05-05 07:15:00             20
# 23 2025-05-05 06:55:00       07:21 2025-05-05 07:21:00             26
# 24 2025-05-05 07:00:00       07:36 2025-05-05 07:36:00             36
# 25 2025-05-05 07:00:00       07:33 2025-05-05 07:33:00             33
# 26 2025-05-05 07:05:00       07:26 2025-05-05 07:26:00             21
# 27 2025-05-05 07:05:00       07:23 2025-05-05 07:23:00             18
# 28 2025-05-05 07:05:00       07:34 2025-05-05 07:34:00             29
# 29 2025-05-05 07:05:00       07:19 2025-05-05 07:19:00             14
# 30 2025-05-05 07:05:00         NaN 2025-05-05 00:00:00           -425
# 31 2025-05-05 07:10:00       07:29 2025-05-05 07:29:00             19
# 32 2025-05-05 07:10:00       07:31 2025-05-05 07:31:00             21
# 33 2025-05-05 07:10:00       07:41 2025-05-05 07:41:00             31
# 34 2025-05-05 07:10:00       07:43 2025-05-05 07:43:00             33
# 35 2025-05-05 07:15:00       07:52 2025-05-05 07:52:00             37
# 36 2025-05-05 07:15:00       07:37 2025-05-05 07:37:00             22
# 37 2025-05-05 07:15:00       08:00 2025-05-05 08:00:00             45
# 38 2025-05-05 07:20:00       07:56 2025-05-05 07:56:00             36
# 39 2025-05-05 07:20:00       07:47 2025-05-05 07:47:00             27
# 40 2025-05-05 07:20:00       07:39 2025-05-05 07:39:00             19
# 41 2025-05-05 07:20:00       07:46 2025-05-05 07:46:00             26
# 42 2025-05-05 07:25:00       07:49 2025-05-05 07:49:00             24
# 43 2025-05-05 07:25:00       08:14 2025-05-05 08:14:00             49
# 44 2025-05-05 07:25:00       08:04 2025-05-05 08:04:00             39
# 45 2025-05-05 07:30:00       07:44 2025-05-05 07:44:00             14
# 46 2025-05-05 07:30:00       08:07 2025-05-05 08:07:00             37
# 47 2025-05-05 07:30:00       07:58 2025-05-05 07:58:00             28
# 48 2025-05-05 07:30:00       07:54 2025-05-05 07:54:00             24
# 49 2025-05-05 07:35:00       08:05 2025-05-05 08:05:00             30
#
#
# DESTINATION_CLEAN            object
# IATA_CODE                    object
# AIRLINE_CLEAN                object
# AIRCRAFT_SHORT               object
# CANCELED                       bool
# DATETIME             datetime64[ns]
# DEPART_TIME                  object
# DEPART_DATETIME      datetime64[ns]
# DELAY_MINUTES                 int64
# dtype: object
# (390, 9)

# %% [markdown]
# ## Count missing values in columns

# %%
# Count missing values per column
print(flightradar_clean.isnull().sum())

# Total number of missing values in the DataFrame
print("Total missing values:", flightradar_clean.isnull().sum().sum())
# Out:
# DESTINATION_CLEAN    0
# IATA_CODE            0
# AIRLINE_CLEAN        7
# AIRCRAFT_SHORT       0
# CANCELED             0
# DATETIME             0
# DEPART_TIME          7
# DEPART_DATETIME      0
# DELAY_MINUTES        0
# dtype: int64
# Total missing values: 14

# %% [markdown]
# ## Show rows with missing values in the DataFrame

# %%
# Filter rows with any missing values
missing_rows = flightradar_clean[flightradar_clean.isnull().any(axis=1)]

# Display rows with missing values
print(missing_rows)
# Out:
#     DESTINATION_CLEAN IATA_CODE AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 1            Pristina       PRN    Flexflight            320     False
# 15           Hurghada       HRG    Flexflight            320     False
# 30             London       LHR         Swiss           A20N     False
# 55             Madrid       MAD           NaN           CL60     False
# 108            Venice       TSF           NaN           BE20     False
# 145          Tel Aviv       TLV         Swiss           A333      True
# 210             Paris       LBG           NaN           E55P     False
# 238             Olbia       OLB           NaN           PC12     False
# 250              Riga       RIX           NaN           C680     False
# 251            Rimini       RMI           NaN           P180     False
# 314         Innsbruck       INN           NaN           CL60     False
# 329          Helsinki       HEL       Finnair           A321      True
# 345           Cologne       CGN     Eurowings           B738      True
# 384         Singapore       SIN         Swiss           B77W      True
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 1   2025-05-05 05:45:00         NaN 2025-05-05 00:00:00           -345
# 15  2025-05-05 06:45:00         NaN 2025-05-05 00:00:00           -405
# 30  2025-05-05 07:05:00         NaN 2025-05-05 00:00:00           -425
# 55  2025-05-05 07:40:00       07:59 2025-05-05 07:59:00             19
# 108 2025-05-05 10:00:00       10:05 2025-05-05 10:05:00              5
# 145 2025-05-05 11:50:00         NaN 2025-05-05 00:00:00           -710
# 210 2025-05-05 13:30:00       13:47 2025-05-05 13:47:00             17
# 238 2025-05-05 15:30:00       15:43 2025-05-05 15:43:00             13
# 250 2025-05-05 16:00:00       16:57 2025-05-05 16:57:00             57
# 251 2025-05-05 16:15:00       16:37 2025-05-05 16:37:00             22
# 314 2025-05-05 18:10:00       19:01 2025-05-05 19:01:00             51
# 329 2025-05-05 19:05:00         NaN 2025-05-05 00:00:00          -1145
# 345 2025-05-05 20:30:00         NaN 2025-05-05 00:00:00          -1230
# 384 2025-05-05 22:40:00         NaN 2025-05-05 00:00:00          -1360

# %% [markdown]
# ## Show the DataFrame without missing values

# %%
# Drop rows with any missing values (NaN)
flightradar_clean = flightradar_clean.dropna(axis=0)

# Display the DataFrame after dropping rows with missing values
print(flightradar_clean)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Larnaca       LCA     Edelweiss Air           A320     False
# 2            Pristina       PRN    Chair Airlines           A320     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4           Heraklion       HER     Edelweiss Air           A320     False
# 5             Antalya       AYT     Edelweiss Air           A320     False
# ..                ...       ...               ...            ...       ...
# 385      Johannesburg       JNB             Swiss           A343     False
# 386         Sao Paulo       GRU             Swiss           B77W     False
# 387         Hong Kong       HKG             Swiss           B77W     False
# 388             Milan       MXP  Helvetic Airways           E190     False
# 389            Geneva       GVA             Swiss           BCS1     False
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0   2025-05-05 05:45:00       06:09 2025-05-05 06:09:00             24
# 2   2025-05-05 05:45:00       06:00 2025-05-05 06:00:00             15
# 3   2025-05-05 06:00:00       06:07 2025-05-05 06:07:00              7
# 4   2025-05-05 06:00:00       06:12 2025-05-05 06:12:00             12
# 5   2025-05-05 06:10:00       06:21 2025-05-05 06:21:00             11
# ..                  ...         ...                 ...            ...
# 385 2025-05-05 22:40:00       23:24 2025-05-05 23:24:00             44
# 386 2025-05-05 22:40:00       23:19 2025-05-05 23:19:00             39
# 387 2025-05-05 22:40:00       23:23 2025-05-05 23:23:00             43
# 388 2025-05-05 22:40:00       23:15 2025-05-05 23:15:00             35
# 389 2025-05-05 22:45:00       23:29 2025-05-05 23:29:00             44
#
# [376 rows x 9 columns]

# %% [markdown]
# ## Check for duplicate rows in the DataFrame and display them if any exist

# %%
# Duplikate prüfen
duplicates = flightradar_clean[flightradar_clean.duplicated()]

# Duplikate anzeigen (falls vorhanden)
print(duplicates)

# Anzahl der Duplikate
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [DESTINATION_CLEAN, IATA_CODE, AIRLINE_CLEAN, AIRCRAFT_SHORT, CANCELED, DATETIME, DEPART_TIME, DEPART_DATETIME, DELAY_MINUTES]
# Index: []
# Number of duplicate rows: 0

# %% [markdown]
# ## Save the cleaned DataFrame to a CSV file for further use or analysis

# %%
# Speichern des DataFrames als CSV-Datei
flightradar_clean.to_csv("250505_flightradar_prepared.csv", index=False)
